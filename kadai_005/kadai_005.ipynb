# %% [markdown]
# <a href="https://colab.research.google.com/github/taniharu1229/data-analysis-basic-kadai/blob/main/kadai_005/kadai_005.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x = [0, 2, 4, 5]
y = [1, 2, -5, 2]
plt.plot(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np

#データを作成
#0から10までの幅で配列を等間隔に100個作成する
x = np.linspace(0, 10, 100)
y = 2 + 2 * np.sin(2 * x)

#プロット
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(0, 10), xticks=np.arange(0, 10),
       ylim=(-1, 5), yticks=np.arange(-1, 6))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np

#データを作成
#0から10までの幅で配列を等間隔に30個作成する
x = np.linspace(0, 10, 30)
y = 2 + 2 * np.sin(2 * x)

#プロット
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(0, 10), xticks=np.arange(0, 10),
       ylim=(-1, 5), yticks=np.arange(-1, 6))
plt.show()

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img = mpimg.imread("risu.jpg")
plt.imshow(img)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img = mpimg.imread("risu.jpg")
img = img[:, :, 1]
plt.imshow(img)
plt.colorbar()

# %%
img = mpimg.imread("risu.jpg")
img = img[:, :, 0]
plt.imshow(img, cmap="gray")

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random .normal(15, 5, 2000)
plt.xlim(-10, 40)
plt.hist(x, 30)
# Out:
# (array([  1.,   1.,   3.,   1.,   4.,  10.,  11.,  34.,  41.,  61.,  90.,
#         108., 158., 176., 186., 177., 202., 177., 132., 112.,  97.,  79.,
#          52.,  34.,  31.,  11.,   4.,   4.,   2.,   1.]),
#  array([-4.22007301, -2.99498491, -1.76989681, -0.5448087 ,  0.6802794 ,
#          1.9053675 ,  3.1304556 ,  4.3555437 ,  5.5806318 ,  6.80571991,
#          8.03080801,  9.25589611, 10.48098421, 11.70607231, 12.93116042,
#         14.15624852, 15.38133662, 16.60642472, 17.83151282, 19.05660092,
#         20.28168903, 21.50677713, 22.73186523, 23.95695333, 25.18204143,
#         26.40712954, 27.63221764, 28.85730574, 30.08239384, 31.30748194,
#         32.53257004]),
#  <BarContainer object of 30 artists>)

# %%
pip install japanize-matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 33.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for japanize-matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=abd8f6e0a47472b84510eb3ed997c586e5f7ce99adde1878ba57b69f221ca70c
#   Stored in directory: /root/.cache/pip/wheels/da/a1/71/b8faeb93276fed10edffcca20746f1ef6f8d9e071eee8425fc
# Successfully built japanize-matplotlib
# ...

# %%
import matplotlib.pyplot as plt
import japanize_matplotlib
hertz = [300, 200, 200, 500, 600, 2000, 1600, 1800, 1850, 1700, 1500, 1500, 1500, 1400, 5000, 6000, 2000, 3000, 300]
plt.boxplot(hertz)
plt.title("モーター音の周波数")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(3)
x = 4 + np.random.normal(0, 2, 60)
y = 4 + np.random.normal(0, 2, len(x))

plt.scatter(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib

x = np.array([30, 40, 30])
label = ["いぬ", "ネコ","その他"]
plt.title("好きな動物")
plt.pie(x, labels=label)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9b143a9650>,
# ...
#  [Text(0.6465637441936395, 0.8899187180267095, 'いぬ'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'ネコ'),
#   Text(0.646563910834035, -0.8899185969553609, 'その他')])

# %%
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib

x = np.array([1, 2, 3, 4, 5])
y = np.array([100, 120, 150, 200, 160])
label = ["昆布", "うめ", "鮭", "カルビ", "すじこ"]
plt.title("おにぎりの具ごとの値段")
plt.bar(x, y, tick_label=label)
# Out:
# <BarContainer object of 5 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(2, 3, tight_layout=True)
y0 = [1, 2, -5, 2]
ax[0,0].plot(y0)

x1 = np.linspace(0, 10, 100)
y1 = 2 + 2 * np.sin(2 * x1)
ax[0, 1].plot(x1, y1)

x2 = np.random.normal(15, 5, 2000)
ax[0, 2].hist(x2)


np.random.seed(3)
x3 = 4 + np.random.normal(0, 2, 60)
y3 = 4 + np.random.normal(0, 2, len(x3))
ax[1, 0].scatter(x3, y3)
plt.show()
